# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2

# %%
path = 'flickr30k_images'
files = os.listdir(path)

# %%
files = files[-40:len(files)]

# %%
for i in range(5):
    image = plt.imread(f'{path}/{files[i]}')
    plt.imshow(image)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4008\414626876.py in <cell line: 1>()
#       1 for i in range(5):
# ----> 2     image = plt.imread(f'{path}/{files[i]}')
#       3     plt.imshow(image)
#       4     plt.show()
#
# C:\anaconda3\envs\machine\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2137 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2138 def imread(fname, format=None):
# -> 2139     return matplotlib.image.imread(fname, format)
#    2140
#    2141
#
# C:\anaconda3\envs\machine\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1558                     response = io.BytesIO(response.read())
#    1559                 return imread(response, format=ext)
# -> 1560     with img_open(fname) as image:
#    1561         return (_pil_png_to_float_array(image)
#    1562                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# C:\anaconda3\envs\machine\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    3066
#    3067     if filename:
# -> 3068         fp = builtins.open(filename, "rb")
#    3069         exclusive_fp = True
#    3070
#
# PermissionError: [Errno 13] Permission denied: 'flickr30k_images/flickr30k_images'

# %%
def add_noise(img):
    image = cv2.GaussianBlur(img, (5, 5), cv2.BORDER_DEFAULT)

    return image




args = dict(
            preprocessing_function=add_noise,
           )

# %%
img_datagen = ImageDataGenerator(**args)
img_datagen2 = ImageDataGenerator()

# %%
images  = img_datagen.flow_from_directory(path,
                                          target_size=(250,250),
                                          batch_size=5)

images2 = img_datagen2.flow_from_directory(path,
                                          target_size=(250,250),
                                          batch_size=5)

datagen = zip(images,images2)
# Out:
# Found 31783 images belonging to 1 classes.
# Found 31783 images belonging to 1 classes.

# %%
xtrain,ytrain = next(datagen)
xtrain[0].shape
# Out:
# (5, 250, 250, 3)

# %%
plt.imshow(xtrain[0][0].astype(np.uint8))
plt.show()
plt.imshow(ytrain[0][0].astype(np.uint8))
plt.show()
